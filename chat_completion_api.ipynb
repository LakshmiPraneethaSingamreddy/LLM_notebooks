# %% [markdown]
# ### A simple call to OpenAi And Google's LLM using chat completions API of OpenAI

# %%
import os
import openai
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv(override=True)
openai_key = os.getenv("OPENAI_API_KEY")
google_key = os.getenv("GOOGLE_API_KEY")

GEMINI_BASE_URL="https://generativelanguage.googleapis.com/v1beta/openai/"

openai = OpenAI()
gemini = OpenAI(base_url=GEMINI_BASE_URL,api_key = google_key)

# %%
message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role":"user","content":message}]

# %%
openai_response = openai.chat.completions.create(model="gpt-5-nano",messages = messages)
print(openai_response.choices[0].message.content)
# Out:
# Hi there! Welcome—great to meet you. I’m here to help with questions, explanations, writing, planning, brainstorming, and more.
#
# What would you like to do today? A few ideas:
# - Explain a topic in simple terms
# - Draft or edit something
# - Solve a math problem or logic puzzle
# - Plan a trip or project
# - Learn something new or practice a skill
# - Brainstorm ideas
#
# If you want, tell me a bit about your interests or just dive in with a question.

# %%
gemini_response = gemini.chat.completions.create(model="gemini-2.5-flash",messages= messages)
print(gemini_response.choices[0].message.content)
# Out:
# Hello there! It's great to "meet" you!
#
# Welcome to our first conversation. I'm here and ready when you are. How can I help you today, or what's on your mind?
